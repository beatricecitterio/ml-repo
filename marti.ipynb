# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('OmicsExpressionProteinCodingGenesTPMLogp1.csv')

# %%
display(df.head())
# Out:
#    Unnamed: 0  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# 0  ACH-001113       4.331992      0.000000     7.364660       2.792855
# 1  ACH-001289       4.567424      0.584963     7.106641       2.543496
# 2  ACH-001339       3.150560      0.000000     7.379118       2.333424
# 3  ACH-001979       4.240314      0.000000     5.681168       2.063503
# 4  ACH-002438       4.032101      0.000000     6.674687       2.117695
#
#    C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  ...  \
# 0          4.471187    0.028569    1.226509      3.044394     6.500005  ...
# 1          3.504620    0.000000    0.189034      3.813525     4.221877  ...
# 2          4.228049    0.056584    1.310340      6.687201     3.682573  ...
# 3          1.641546    0.000000    7.236301      5.948367     4.596935  ...
# 4          3.003602    0.000000    2.169925      6.838195     3.253989  ...
#
#    H3C2 (8358)  H3C3 (8352)  AC098582.1 (8916)  DUS4L-BCAP29 (115253422)  \
# ...

# %%
df2 = pd.read_csv('OmicsSomaticMutations.csv', index_col=0)
# Out:
# /var/folders/r9/tk3nsgjj4_j4z3n_rxsd7s580000gn/T/ipykernel_37648/2222604753.py:1: DtypeWarning: Columns (22,50,56,57,58,59,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('OmicsSomaticMutations.csv', index_col=0)

# %%
display(df2.head())
# Out:
#           Pos Ref Alt     AF  DP  RefCount  AltCount   GT        PS  \
# Chrom
# chr1   818203   G   A  0.240  27        21         6  0/1       NaN
# chr1   851926   G   A  0.158  17        15         2  0/1       NaN
# chr1   924510  GC  AA  0.412  35        21        14  0|1  924510.0
# chr1   924657   C   G  0.437  17         9         8  0/1       NaN
# chr1   924750   C   T  0.625  19         7        12  0/1       NaN
#
#         VariantType  ... GwasPmID GtexGene ProveanPrediction AMClass  \
# Chrom                ...
# chr1            SNV  ...      NaN      NaN               NaN     NaN
# chr1            SNV  ...      NaN      NaN               NaN     NaN
# chr1   substitution  ...      NaN      NaN               NaN     NaN
# chr1            SNV  ...      NaN      NaN               NaN     NaN
# chr1            SNV  ...      NaN      NaN               NaN     NaN
#
#       AMPathogenicity Rescue RescueReason     ModelID Hotspot EntrezGeneID
# Chrom
# ...
