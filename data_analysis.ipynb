# %% [markdown]
# # **Exploratory Data Analysis**
# In this notebook we load the data we chose, we inspect it and try to understand what it represents and how to build the optimal dataset for our classifier.

# %%
import pandas as pd

# %% [markdown]
# ## **Data Loading**
# We found a dataset on CCLE, called <code>CCLE_RNAseq_genes_rpkm_20180929</code>

# %%
import zipfile

with zipfile.ZipFile('ccle.zip', 'r') as zipf:
    zipf.extractall()

# %%
# we prepare the df to have the cell lines as rows and the genes as columns
df = pd.read_csv('CCLE_RNAseq_genes_rpkm_20180929.gct', sep='\t', skiprows=2)
df.drop(columns=['Name'], inplace=True)
df.rename(columns={'Description': 'Gene'}, inplace=True)
df.set_index('Gene', inplace=True)

df = df.T
df.columns.name = None
df.head()
# Out:
#                                 DDX11L1   WASH7P  MIR1302-11   FAM138A  \
# 22RV1_PROSTATE                 0.053448  5.75256    0.039576  0.037401
# 2313287_STOMACH                0.043078  4.26104    0.011961  0.022608
# 253JBV_URINARY_TRACT           0.037956  3.10048    0.031618  0.013280
# 253J_URINARY_TRACT             0.028313  3.07909    0.031446  0.026416
# 42MGBA_CENTRAL_NERVOUS_SYSTEM  0.009377  3.99494    0.020830  0.006562
#
#                                  OR4G4P   OR4G11P     OR4F5  RP11-34P13.7  \
# 22RV1_PROSTATE                 0.000000  0.032334  0.049664      0.077574
# 2313287_STOMACH                0.019401  0.048864  0.080056      0.044659
# 253JBV_URINARY_TRACT           0.025642  0.025833  0.008817      0.011805
# 253J_URINARY_TRACT             0.008501  0.042820  0.035077      0.023481
# 42MGBA_CENTRAL_NERVOUS_SYSTEM  0.008447  0.008509  0.017427      0.023332
#
#                                  CICP27  AL627309.1  ...    MT-ND4     MT-TH  \
# 22RV1_PROSTATE                 0.098682    3.349550  ...   6914.89  0.770865
# 2313287_STOMACH                0.098997    4.049520  ...   8190.65  0.532545
# 253JBV_URINARY_TRACT           0.149851    0.212384  ...   6250.53  0.586535
# 253J_URINARY_TRACT             0.100099    0.131432  ...  12656.70  0.933357
# 42MGBA_CENTRAL_NERVOUS_SYSTEM  0.053046    0.069961  ...   4004.12  0.231852
#
#                                  MT-TS2    MT-TL2   MT-ND5   MT-ND6    MT-TE  \
# 22RV1_PROSTATE                 0.901520  1.177240  2324.83  1794.95  4.62519
# 2313287_STOMACH                0.467105  0.517544  1909.74  1974.76  3.06213
# 253JBV_URINARY_TRACT           0.548758  1.824040  1822.52  2097.98  1.29038
# 253J_URINARY_TRACT             1.228000  1.814130  3220.78  3909.72  3.85010
# 42MGBA_CENTRAL_NERVOUS_SYSTEM  0.813448  0.450643  1158.29  1622.68  2.55038
#
#                                 MT-CYB     MT-TT     MT-TP
# 22RV1_PROSTATE                 4630.21  0.230258  0.446972
# 2313287_STOMACH                3685.24  0.000000  0.270188
# 253JBV_URINARY_TRACT           1778.51  0.613195  1.309350
# 253J_URINARY_TRACT             4159.00  0.853810  2.486090
# 42MGBA_CENTRAL_NERVOUS_SYSTEM  2215.69  0.121196  0.117631
#
# [5 rows x 56202 columns]

# %%
df.isna().sum().sum()  # check for missing values
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                                 DDX11L1   WASH7P  MIR1302-11   FAM138A  \
# 22RV1_PROSTATE                 0.053448  5.75256    0.039576  0.037401
# 2313287_STOMACH                0.043078  4.26104    0.011961  0.022608
# 253JBV_URINARY_TRACT           0.037956  3.10048    0.031618  0.013280
# 253J_URINARY_TRACT             0.028313  3.07909    0.031446  0.026416
# 42MGBA_CENTRAL_NERVOUS_SYSTEM  0.009377  3.99494    0.020830  0.006562
#
#                                  OR4G4P   OR4G11P     OR4F5  RP11-34P13.7  \
# 22RV1_PROSTATE                 0.000000  0.032334  0.049664      0.077574
# 2313287_STOMACH                0.019401  0.048864  0.080056      0.044659
# 253JBV_URINARY_TRACT           0.025642  0.025833  0.008817      0.011805
# 253J_URINARY_TRACT             0.008501  0.042820  0.035077      0.023481
# 42MGBA_CENTRAL_NERVOUS_SYSTEM  0.008447  0.008509  0.017427      0.023332
#
#                                  CICP27  AL627309.1  ...    MT-ND4     MT-TH  \
# 22RV1_PROSTATE                 0.098682    3.349550  ...   6914.89  0.770865
# 2313287_STOMACH                0.098997    4.049520  ...   8190.65  0.532545
# 253JBV_URINARY_TRACT           0.149851    0.212384  ...   6250.53  0.586535
# 253J_URINARY_TRACT             0.100099    0.131432  ...  12656.70  0.933357
# 42MGBA_CENTRAL_NERVOUS_SYSTEM  0.053046    0.069961  ...   4004.12  0.231852
#
#                                  MT-TS2    MT-TL2   MT-ND5   MT-ND6    MT-TE  \
# 22RV1_PROSTATE                 0.901520  1.177240  2324.83  1794.95  4.62519
# 2313287_STOMACH                0.467105  0.517544  1909.74  1974.76  3.06213
# 253JBV_URINARY_TRACT           0.548758  1.824040  1822.52  2097.98  1.29038
# 253J_URINARY_TRACT             1.228000  1.814130  3220.78  3909.72  3.85010
# 42MGBA_CENTRAL_NERVOUS_SYSTEM  0.813448  0.450643  1158.29  1622.68  2.55038
#
#                                 MT-CYB     MT-TT     MT-TP
# 22RV1_PROSTATE                 4630.21  0.230258  0.446972
# 2313287_STOMACH                3685.24  0.000000  0.270188
# 253JBV_URINARY_TRACT           1778.51  0.613195  1.309350
# 253J_URINARY_TRACT             4159.00  0.853810  2.486090
# 42MGBA_CENTRAL_NERVOUS_SYSTEM  2215.69  0.121196  0.117631
#
# [5 rows x 56202 columns]

# %% [markdown]
# ### **TP53 Mutation DB**
# [Link to the TP53 website 1](https://p53.fr/download-the-database)
#
# [Link to the TP53 website 2](https://tp53.cancer.gov/get_tp53data#get_annot)

# %%
mut = pd.read_csv('CellLineDownload_r21.csv')

# %%
mut.head()
# Out:
#    Sample_ID Sample_Name    ATCC_ID  Cosmic_ID     Short_topo  \
# 0       2946        SW13    CCL-105   909744.0  ADRENAL GLAND
# 1      24833    NCI-H295  CRL-10296   908466.0  ADRENAL GLAND
# 2      24979   NCI-H295R   CRL-2128        NaN  ADRENAL GLAND
# 3      21569    NCI-H295  CRL-10296   908466.0  ADRENAL GLAND
# 4      21329       ETK-1        NaN   906861.0  BILIARY TRACT
#
#                            Morphology Tumor_origin  \
# 0  Adrenal cortical carcinoma (C74.0)          NaN
# 1  Adrenal cortical carcinoma (C74.0)          NaN
# 2  Adrenal cortical carcinoma (C74.0)      primary
# 3  Adrenal cortical carcinoma (C74.0)          NaN
# 4                 Adenocarcinoma, NOS          NaN
#
#                           Add_info Sex   Age  ...  exon2  exon3  exon4 exon5  \
# 0                              NaN   F  55.0  ...  False  False  False  True
# 1                              NaN   F  48.0  ...  False  False  False  True
# 2  Derived from NCI-H295 cell line   F  48.0  ...   True   True   True  True
# 3                              NaN   F  48.0  ...   True   True   True  True
# 4                              NaN   F   NaN  ...   True   True   True  True
#
#   exon6 exon7 exon8  exon9 exon10 exon11
# 0  True  True  True  False  False  False
# 1  True  True  True  False  False  False
# 2  True  True  True   True   True   True
# 3  True  True  True   True   True   True
# 4  True  True  True   True   True   True
#
# [5 rows x 80 columns]

# %%
cell_lines_mut = mut['Sample_Name']
cell_lines_mut_names = []
for cell in cell_lines_mut.values:
    cell = str(cell).lower()
    cell = cell.replace('_', '') 
    cell = cell.replace('-', '') 
    cell = cell.replace('.', '') 
    cell = cell.replace(' ', '') 

    cell_lines_mut_names.append(cell)

# %%
cell_lines_mut_names
# Out:
# ['sw13',
#  'ncih295',
#  'ncih295r',
#  'ncih295',
#  'etk1',
#  'tgbc1tkb',
#  'egi1',
#  'snu478',
#  'snu869',
#  'snu1196',
#  'snu245',
#  'hucct1',
#  'tgbc24tkb',
#  'huh28',
#  'snu1079',
#  'cubiii',
#  'ej',
#  'ld700',
#  'ld627',
#  'ld660',
#  'ld692',
#  'ld630',
#  '5637',
#  'scaber',
#  'sd',
#  'fhs738b1',
#  'ht1197',
#  'dsh1',
#  'lb831blc',
#  'jmsu1',
#  'bftc905',
#  'j82',
#  'j82',
#  'j82',
#  'j82',
#  'j82',
#  'ht1376',
#  't24p',
#  't24a',
#  'tccsup',
#  'sw1710',
#  'rt112',
#  'rt112',
#  'cal29',
#  't24',
#  'umuc3',
#  'vmcub1',
#  'vmcub1',
#  'umuc1',
#  'vmcub2',
#  'bftc909',
#  'bt1',
#  'ej',
#  'sd',
#  'vmcub3',
#  'ucrubl17',
#  '647v',
#  '647v',
#  'hs172t',
#  '253j',
#  '486p',
#  'ld583',
#  'ld611',
#  'ld71',
#  'sw780',
#  'bc3c',
#  'ht1197',
#  'ku1919',
#  '253jbv',
#  'rt4',
#  'sw1353',
#  'cal78',
#  'rdes',
#  'tc71',
#  'hossl',
#  'huo9',
#  'u2os',
#  'sjsa1',
#  'oums27',
#  'g292clonea141b1',
#  'mg63',
#  'hc98',
#  'jj',
#  'staet21',
#  'ham9458',
#  'ham9459',
#  'ham9463',
#  'mhhes1',
#  'scmces1',
#  'wes',
#  'es1ot',
#  'rdes',
#  'scmces2',
#  'a673',
#  'es1',
#  'ew11',
#  'ew12',
#  'rm82',
#  'skes1',
#  'staet21',
#  'ew3',
#  'es3',
#  'es5',
#  'es6',
#  'es7',
#  'es8',
#  'ew1',
#  'skpndw',
#  'iarcew2',
#  'staet71',
#  'staet72',
#  'smb',
#  'ew13',
#  'ew13',
#  'ew16',
#  'ew18',
#  'ew22',
#  'ew24',
#  'htk',
#  'ndcs1',
#  'hosm2',
#  'rit1b',
#  'rit2',
#  '143b',
#  'huo3n1',
#  'g292',
#  'hos/mnng',
#  'hos',
#  'hos143b',
#  'ior/mos',
#  'ohs/x',
#  'mg63',
#  'ior/os18',
#  'ior/sarg',
#  'htla161',
#  '8842',
#  '7922',
#  'hs870t',
#  'hoc605',
#  'nu',
#  'saos2',
#  'l13t',
#  'hemcss',
#  'ch2879',
#  'hs819t',
#  'cadoes1',
#  'scch196',
#  'sal1',
#  'sal2',
#  'staet1',
#  'we68',
#  'wem268',
#  'ew7',
#  'vh64',
#  'es4',
#  'ew3',
#  'staet3',
#  'staet4',
#  'staet5',
#  'staet6',
#  'staet8',
#  'fpbh',
#  'tc252',
#  'hs706t',
#  'hs737t',
#  'hs821t',
#  'l13n',
#  'ior/os10',
#  'ior/os15',
#  'kpd',
#  'cal72',
#  'hal',
#  'ior/os14',
#  'ior/os9',
#  'mhm',
#  'osa(sjsa1)',
#  'zk58',
#  'hs888t',
#  'ny',
#  'cniobj',
#  'ti73',
#  't173',
#  'staet10',
#  'b217',
#  'sw1088',
#  'ln319',
#  'u373mg',
#  '1321n1',
#  'moggccm',
#  'mogguvw',
#  'd263mg',
#  'd336mg',
#  'd423mg',
#  'd566mg',
#  'skmg1',
#  'tm31',
#  'mgr1',
#  'no11',
#  'kings1',
#  'kings1',
#  'no10',
#  'kog962',
#  'kog964',
#  'kog965',
#  'onda11',
#  'sw1783',
#  'sw1783',
#  'hug27',
#  'hug31',
#  'hug19',
#  'sjg5',
#  'snb78',
#  'g210gm',
#  'g211gm',
#  'g599gm',
#  'g750gm',
#  'g1163gm',
#  'g1187gm',
#  'g1265gm',
#  'g1301gm',
#  'nceg22',
#  'nceg22',
#  'nceg112',
#  'nceg123',
#  'nceg123',
#  'nceg44',
#  'nceg84',
#  'nceg62',
#  'nceg130',
#  'hug9',
#  'hug15',
#  'snu626',
#  'snu1105',
#  'gm97',
#  'gm2328',
#  'gm2313',
#  'gm2217',
#  'gm2345',
#  'gm2493',
#  'gm1596',
#  'gm133',
#  'lg',
#  'sjg2',
#  'sjg3',
#  'mgr2',
#  'g22',
#  'g112',
#  'g122',
#  'g140',
#  'g59',
#  'g123',
#  'hgg02',
#  'ln229',
#  '8mgba',
#  'ln405',
#  'onda10',
#  'ykg1',
#  'u251mg',
#  'u118mg',
#  'a172',
#  'snb19',
#  'becker',
#  'cas1',
#  'gb1',
#  'gms10',
#  'u138mg',
#  'u138mg',
#  'yh13',
#  'm059k',
#  '42mgba',
#  '42mgba',
#  'snb19',
#  'ln18',
#  'ln428',
#  'ln428',
#  't98g',
#  'a7',
#  'd456',
#  'gt9',
#  'hug34',
#  'hug11',
#  'hug20',
#  'gm4723',
#  'tk1',
#  'gli36degfr',
#  'gamg',
#  'kals1',
#  'ln229',
#  'kns42',
#  'hs683',
#  'kns60',
#  'sf188',
#  'sf210',
#  'sf268',
#  'skmg12',
#  'm059j',
#  'sf295',
#  'snb75',
#  'snb75',
#  'd542mg',
#  'u138mg',
#  'gi1',
#  'kns89',
#  'daoy',
#  'uw228',
#  'vmg35/ce',
#  'skmg16',
#  'skmg21',
#  'skmg8',
#  'skd1',
#  'vmg6/stt',
#  'vmg6/stt',
#  'sknmc',
#  'snu738',
#  'pfsk1',
#  'd397mg',
#  'sf126',
#  'g130',
#  'ln308',
#  'd54mg',
#  'd245mg',
#  'd392mg',
#  'd502mg',
#  'd538mg',
#  'd247mg',
#  'nceg168',
#  'nceg63',
#  'nceg120',
#  'efc2',
#  'mgr3',
#  'uw28',
#  'uw281',
#  'uw78',
#  'g96',
#  'g61',
#  'g63',
#  'g60',
#  'g118',
#  'g62',
#  'g44',
#  'g120',
#  'g121',
#  'g168',
#  'u87mg',
#  'ccfsttg1',
#  'dbtrg05mg',
#  'dkmg',
#  'ks1',
#  'marcus',
#  'a172',
#  'am38',
#  'g1408gm',
#  'gm139',
#  'gm1578',
#  'gm1592',
#  'gm1600',
#  'gm2300',
#  'gm2401',
#  'gm2455',
#  'nmcg1',
#  'hug2',
#  'hug16',
#  'hug21',
#  'hug23',
#  'hug25',
#  'hug30',
#  'hug33',
#  'hug35',
#  'sf767',
#  'h4',
#  'kns81fd',
#  'kg1c',
#  'kns81',
#  'snu466',
#  'sf539',
#  'd247mg',
#  'ln229',
#  'd283med',
#  'd341med',
#  'd384med',
#  'd458med',
#  'd556med',
#  'gos3',
#  'hug17',
#  'ons76',
#  'hs822t',
#  'hs863t',
#  'mdamb231',
#  'mdamb468',
#  'skbr3',
#  'mdamb436',
#  'cama1',
#  'mdamb361',
#  'au565',
#  'mdamb415',
#  'mdamb436',
#  'hs739t',
#  'efm192a',
#  'mw1c63',
#  '21pt',
#  '21nt',
#  '21mt1',
#  '21mt2',
#  'hcc1007',
#  'hmt3909',
#  'brc230',
#  'mast',
#  'sum1315mo2',
#  'sum159pt',
#  'skbr5',
#  'mdamb330',
#  'sum149pt',
#  'evsat',
#  'ocubf',
#  'bt483',
#  'sum225cwn',
#  'sum229pe',
#  'sum44pe',
#  'sum185pe',
#  'sum52pe',
#  'sum190pt',
#  'mdan',
#  'bsy1',
#  'hbc5',
#  'h31',
#  'h71',
#  'bt20',
#  'mcf7/adr',
#  'hdqp1',
#  'mdamb361',
#  'cal120',
#  'cal851',
#  'ocubm',
#  'mdamb453',
#  'jimt1',
#  'nciadrres',
#  'mdamb453',
#  'hs578t',
#  'tom98',
#  'hcc38',
#  'hcc70',
#  'hcc1395',
#  'hcc1937',
#  'hcc2218',
#  'hcc1008',
#  'hcc2713',
#  'bt474',
#  'bt549',
#  't47d',
#  'mdamb435',
#  'uacc893',
#  'bt483',
#  'mdamb134vi',
#  'mdamb134vi',
#  'efm19',
#  'hcc1143',
#  'hcc1187',
#  'hcc1419',
#  'hcc1419',
#  'hcc1599',
#  'hcc1954',
#  'hcc2157',
#  'hcc2218',
#  'hcc202',
#  'mdamb435s',
#  'hcc1143',
#  'hcc1187',
#  'hcc1419',
#  'hcc1428',
#  'hcc2157',
#  'mfm223',
#  'cal148',
#  'mmb1',
#  'mdamb157',
#  'hcc1569',
#  'bt549',
#  'bt549',
#  'hmc18',
#  'hcc1806',
#  'mdamb453',
#  'mcf7',
#  'hbl100',
#  'zr751',
#  'mpe600',
#  'skbr7',
#  'sum102pt',
#  'hbc4',
#  'cal51',
#  'mrknu1',
#  'hs274t',
#  'hs281t',
#  'hs343t',
#  'hs606t',
#  'hs742t',
#  'ymb1',
#  'colo824',
#  'h185',
#  'h62',
#  'mt3',
#  'kpl1',
#  'hcc712',
#  'hcc1143',
#  'hcc1187',
#  'hcc1419',
#  'hcc1500',
#  'hcc1685',
#  'hcc1739',
#  'hcc2157',
#  'hcc2389',
#  'hcc1428',
#  'du4475',
#  'mdamb175vii',
#  'uacc812',
#  'zr7530',
#  'mcf10a',
#  'c33a',
#  'ht3',
#  'omc4',
#  'sks',
#  'tcyik',
#  'igr/cut40',
#  'helasf',
#  'c4ii',
#  'dotc24510',
#  'me180',
#  'ms751',
#  'skgiiia',
#  'umgcc1',
#  'hx151c',
#  'hx156c',
#  'boku',
#  'caski',
#  'siha',
#  'omc1',
#  'sw756',
#  'ca',
#  'snu1235',
#  'snu1197',
#  'snu479',
#  'snu1181',
#  'ncih747',
#  'sw1116',
#  'cl14',
#  'coga5',
#  'widr',
#  'sw48',
#  'ls123',
#  'ls123',
#  'sw403',
#  'sw948',
#  'cl34',
#  'colo320',
#  'dld1',
#  'sw480',
#  'sw480',
#  'hct15',
#  'colo205',
#  'c2bbe1',
#  'colo320hsr',
#  'ls1034',
#  'ls411n',
#  'ncih508',
#  'ncih716',
#  'ncih716',
#  'colo201',
#  'colo205',
#  'snuc1',
#  'km12',
#  'hcc2998',
#  'km12',
#  'cocm1',
#  'ht55',
#  'hcc56',
#  'lt97',
#  'lt97',
#  'vaco8',
#  'vaco489',
#  'vaco576',
#  'vaco703',
#  'vaco457',
#  'vaco5',
#  'vaco670',
#  'snuc4',
#  'snuc5',
#  'snuc5',
#  'h110',
#  'h173',
#  'co74',
#  'co92',
#  'co82',
#  'co84',
#  'colo741',
#  'cw2',
#  'snuc2b',
#  'snuc2a',
#  'cl40',
#  'ls1034',
#  'colo205',
#  'hct15',
#  'hct15',
#  'ls1034',
#  't84',
#  't84',
#  'oums23',
#  'snu407',
#  'hcc2998',
#  'rko',
#  'ht115',
#  'ccl235',
#  'ccl228',
#  'cl11',
#  'fhc',
#  'snu61',
#  'snu1040',
#  'snu1047',
#  'snu81',
#  'snu81',
#  'snu283',
#  'snu1406',
#  'snu1544',
#  'snu1460',
#  'snu1684',
#  'gp5d',
#  'gp2d',
#  'ls174t',
#  'ls174t',
#  'hs255t',
#  'dld1',
#  'ls513',
#  'lovo',
#  'skco1',
#  'hrt18',
#  'hs698t',
#  'sw48',
#  'mdst8',
#  'co108',
#  'co79',
#  'snu175',
#  'hct116',
#  'colo678',
#  'hs675t',
#  'h143',
#  'h26',
#  'lim1215',
#  'snu1746',
#  'car1',
#  'p6',
#  'ht29',
#  'colo320dm',
#  'vaco330',
#  'clonea',
#  'cloned',
#  'cx1',
#  'mip101',
#  'moser',
#  'ala',
#  'cbs',
#  'fet',
#  'gly',
#  'isreco1',
#  'isreco2',
#  'v9p',
#  'tc71',
#  'fri',
#  'pc/jw',
#  'cx27',
#  'sw620',
#  'c10',
#  'c106',
#  'c75',
#  'car1',
#  'cc07',
#  'cck81',
#  'hra19',
#  'ht55',
#  'lim1863',
#  'vaco10ms',
#  'c125pm',
#  'c80',
#  'c84',
#  'caco2',
#  'cc20',
#  'ls411',
#  'vaco429',
#  'c70',
#  'vaco400',
#  'vaco4a',
#  'hca46',
#  'hca7',
#  'sw1417',
#  'km20l2',
#  's/rg',
#  'sw1222',
#  'aa/c1/sb10',
#  'pc/bh',
#  'pc/aa',
#  'aa/c1',
#  'jw',
#  'c32',
#  'c99',
#  'ls180',
#  'huvecs',
#  'col15',
#  's/an',
#  'colo684',
#  'hec6',
#  'hhua',
#  'houa',
#  'ik90',
#  'en',
#  'hec59',
#  'hec116',
#  'hec251',
#  'an3',
#  'hecla',
#  'heclb',
#  'an3ca',
#  'hec1',
#  'mfe280',
#  'mfe296',
#  'hec108',
#  'hec151',
#  'jhuem3',
#  'mfe319',
#  'mfe319',
#  'ten',
#  'ishikawa(heraklio)02er',
#  'ishikawa(heraklio)02er',
#  'ishikawa',
#  'kle',
#  'rl952',
#  'efe184',
#  'hec50co',
#  'ess1',
#  'snu685',
#  'snu1077',
#  'hec155',
#  'hec180',
#  'umec1',
#  'hec6',
#  'hec88',
#  'umec2',
#  'umec3',
#  'utec1',
#  'utec2a',
#  'utec2b',
#  'utec2c',
#  'utec3',
#  'sngm',
#  'jhuem1',
#  'jhuem2',
#  'jhuem7',
#  'hec108',
#  'hec151',
#  'hec265',
#  'oe19',
#  'skgt4',
#  'skgt5',
#  'flo1',
#  'bic1',
#  'bic1',
#  'cp94251',
#  'cp18821',
#  'cp52731',
#  'hce7',
#  'te4',
#  'te14',
#  'ecgi10',
#  'oe33',
#  'te15',
#  'kyse150',
#  'kyse510',
#  'te5',
#  'te1',
#  'te10',
#  'te11',
#  'te6',
#  'kyse140',
#  'kyse180',
#  'kyse270',
#  'kyse410',
#  'kyse450',
#  'kyse70',
#  'kyse70',
#  'te2',
#  'te11',
#  'te7',
#  'kyse110',
#  'kyse1170',
#  'kyse1170',
#  'kyse1240',
#  'kyse1250',
#  'kyse1260',
#  'kyse170',
#  'kyse190',
#  'kyse200',
#  'kyse220',
#  'kyse350',
#  'kyse450',
#  'kyse510',
#  'kyse590',
#  'kyse850',
#  'kyse890',
#  'kyse70',
#  'kyse30',
#  'kyse273',
#  'kyse520',
#  'kyse770',
#  'kyse1140',
#  'tt',
#  'ttn',
#  'colo680n',
#  'te9',
#  'oe21',
#  'kyse410',
#  'hce4',
#  'hce6',
#  'te8',
#  'seg1',
#  'e1n',
#  'het1a',
#  'het1a',
#  'kyse410',
#  'kyse960',
#  'e1t',
#  'te12',
#  'werirb1',
#  'mel270',
#  'mm28',
#  'mm50',
#  'est128',
#  'nuc1',
#  'nuc1',
#  'snu308',
#  'scsc',
#  'utscc1a',
#  'kosc3',
#  'nos1',
#  'utscc33',
#  'mkg7',
#  'bicr31',
#  'bicr16',
#  'hn5',
#  'bicr56',
#  'luhnxscc4',
#  'luhnxscc5',
#  'luhnxscc8',
#  'sas',
#  'scc35',
#  'sq38',
#  'jsq3',
#  'hu281',
#  'mda1186',
#  'mda1386',
#  'mda1386',
#  'mda1586',
#  'mda1686',
#  'mda1686',
#  'mda686tu',
#  'mskqll1',
#  'mskqll2',
#  'hnscc131',
#  'hnscc135',
#  'hnscc152',
#  'hnscc29',
#  'hnscc294',
#  'hnscc301b',
#  'hnscc42',
#  'hnscc80',
#  'jsq13',
#  'scc151',
#  'sq20b',
#  'sq9g',
#  'cellline16',
#  'cellline29b',
#  'cellline32',
#  'cellline36',
#  'cellline70',
#  'cellline72',
#  'cellline77',
#  'cellline84',
#  'cellline99',
#  'cellline103',
#  'cellline105',
#  'cellline111',
#  'cellline114',
#  'cellline116',
#  'cellline122',
#  'cellline125',
#  'cellline136',
#  'cellline172',
#  'cellline182',
#  'umscc10b',
#  'umscc12',
#  'umscc13',
#  'umscc14a',
#  'umscc20',
#  'umscc23',
#  'umscc36',
#  'umscc57',
#  'umscc68',
#  'umscc81b',
#  'mda183',
#  'mda1483',
#  'bb30hnc',
#  'lb771hnc',
#  'luhnxscc3',
#  'luhnxscc6',
#  'luhnxscc7',
#  'umscc17b',
#  'umscc25',
#  'umscc47',
#  'umscc54',
#  'umscc72',
#  'umscc74a',
#  'umscc74b',
#  'umscc81a',
#  'bb49hnc',
#  'accmeso1',
#  'ncih2452',
#  'bt',
#  'tuma',
#  'td',
#  'jmn',
#  'istmes2',
#  'm15',
#  'mpp89',
#  'accmeso1',
#  'accmeso4',
#  'accmeso8a',
#  'accmeso8d',
#  'istmes1',
#  'msto211h',
#  'ncih2052',
#  'ncih28',
#  'dnd',
#  'm9k',
#  'm10k',
#  'm14k',
#  'm14p',
#  'm20',
#  'm19',
#  'm33k',
#  'hut28',
#  'hut226',
#  'hut290',
#  'mt3',
#  'm24k',
#  'm25k',
#  'm28k',
#  'm32k',
#  'vamt1',
#  'chp100',
#  'jjn3',
#  'tmbl1',
#  'ky821',
#  'cmk115',
#  'shi1',
#  'skno1',
#  'ysk21',
#  'hel9217',
#  'ocim2',
#  'k051/52',
#  'kasumi1',
#  'kasumi6',
#  'kbm5',
#  'kbm7',
#  'kmoe2',
#  'nb4',
#  'aml193',
#  'molm16',
#  'molm16',
#  'kg1',
#  'cmk',
#  'cmk',
#  'cmk',
#  'k052',
#  'monomac6',
#  'f36p',
#  'p31fuj',
#  'hel',
#  'nomo1',
#  'ml1(a)',
#  'ml2',
#  'monomac1',
#  'ocim1',
#  'ocim1',
#  'kbm3',
#  'pl21',
#  'd11',
#  'a3/kawa',
#  'a3/kawa',
#  'so4',
#  'kk1',
#  'kk1',
#  'mt1',
#  'mt1s',
#  'khyg1',
#  'cll2',
#  'cll3',
#  ...]

# %%
df.index

count = 0
for cell in df.index:
    cell_name = cell.split('_')[0]
    if str(cell_name).lower() in cell_lines_mut_names:
        count += 1

# %%
count
# Out:
# 949

# %%
print(len(cell_lines_mut.unique()), len(cell_lines_mut))
# Out:
# 2632 2913
